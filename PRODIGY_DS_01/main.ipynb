# %% [markdown]
#  # DATA SCIENCE

# %% [markdown]
# ## DEVELOPED BY AVIJEET MOHAPTRA

# %% [markdown]
# ### Creation of a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style

# %%
dataset = pd.read_csv('datab.csv')

# %%
dataset.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
country=dataset['Country Name']
year=dataset['1960']

# %%
fig=plt.figure(figsize=(20,10))
plt.bar(country,year)
plt.xlabel(' Name of  the country')
plt.ylabel('year')
plt.title('INDICATOR')
plt.show()

# %%
fig=plt.figure(figsize=(20,10))
plt.barh(country,year,color='green')
plt.xlabel(' Name of  the country')
plt.ylabel('year')
plt.title('INDICATOR')
plt.show()

# %%
time_data={'facebook':120,'youtube':90,'instagram':140,'snapchat':120}
social_media=list(time_data.keys())
time_spend=list(time_data.values())

# %%
plt.bar(social_media,time_spend)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(social_media,time_spend,color='pink',width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(5,5))
plt.bar(social_media,time_spend,color='orange',width=0.5)
plt.xlabel('social_media')
plt.ylabel('time in min')
plt.title('avg time spend on social media')
# Out:
# Text(0.5, 1.0, 'avg time spend on social media')

# %%
style.use('ggplot')
plt.figure(figsize=(5,5))
plt.bar(social_media,time_spend,color='black',width=0.5)
plt.xlabel('social_media')
plt.ylabel('time in min')
plt.title('avg time spend on social media')
# Out:
# Text(0.5, 1.0, 'avg time spend on social media')

# %%
style.use('ggplot')
plt.figure(figsize=(5,5))
color=['purple','violet','green','yellow']
plt.bar(social_media,time_spend,color=color,width=0.5)
plt.xlabel('social_media')
plt.ylabel('time in min')
plt.title('avg time spend on social media')
# Out:
# Text(0.5, 1.0, 'avg time spend on social media')

# %%
fb=(120,90,110,100,95)
yt=(80,90,25,85,95)
ig=(50,40,55,35,45)
sc=(20,30,35,25,28)

# %%
xpos=np.arange(len(fb))
xpos
# Out:
# array([0, 1, 2, 3, 4])

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))
barwidth=0.2
plt.bar(xpos,fb,color='royalblue',width=barwidth,label='FB')
# Out:
# <BarContainer object of 5 artists>

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))
barwidth=0.2
plt.bar(xpos,fb,color='royalblue',width=barwidth,label='FB')
plt.bar(xpos+0.2,yt,color='red',width=barwidth,label='YT')
# Out:
# <BarContainer object of 5 artists>

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))
barwidth=0.2
plt.bar(xpos,fb,color='royalblue',width=barwidth,label='FB')
plt.bar(xpos+0.2,yt,color='red',width=barwidth,label='YT')
plt.bar(xpos+0.4,ig,color='green',width=barwidth,label='IG')
plt.bar(xpos+0.6,sc,color='black',width=barwidth,label='SC')
# Out:
# <BarContainer object of 5 artists>

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))
barwidth=0.2
plt.bar(xpos,fb,color='royalblue',width=barwidth,label='FB')
plt.bar(xpos+0.2,yt,color='red',width=barwidth,label='YT')
plt.bar(xpos+0.4,ig,color='green',width=barwidth,label='IG')
plt.bar(xpos+0.6,sc,color='black',width=barwidth,label='SC')
plt.xlabel('day')
plt.ylabel('time spend in min')
plt.legend()

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))
barwidth=0.2
plt.bar(xpos,fb,color='royalblue',width=barwidth,label='FB')
plt.bar(xpos+0.2,yt,color='red',width=barwidth,label='YT')
plt.bar(xpos+0.4,ig,color='green',width=barwidth,label='IG')
plt.bar(xpos+0.6,sc,color='black',width=barwidth,label='SC')
plt.xticks(xpos+0.3,('mon','tue','wed','thu','fri'))
plt.xlabel('day')
plt.ylabel('time spend in min')
plt.title('time spend on social media')
plt.legend()

# %%
fb=(120,90,110,100,95)
yt=(80,90,25,85,95)
x=['mon','tue','wed','thur','fri']
xpos=np.arange(len(x))
barwidth=0.4
plt.figure(figsize=(10,7))
plt.bar(xpos,fb,color='royalblue',width=barwidth,label='FB')
plt.bar(xpos,yt,bottom=fb,color='red',width=barwidth,label='YT')
plt.xlabel('day')
plt.ylabel('time spend in min')
plt.title('time spend on social media')
plt.xticks(xpos,x)
plt.legend()

# %%
fb=(120,90,110,100,95)
yt=(80,90,25,85,95)
ig=(50,40,55,35,45)
x=['mon','tue','wed','thur','fri']
xpos=np.arange(len(x))
barwidth=0.4
plt.figure(figsize=(10,7))
plt.bar(xpos,fb,color='royalblue',width=barwidth,label='FB')
plt.bar(xpos,yt,bottom=fb,color='red',width=barwidth,label='YT')
plt.bar(xpos,ig,bottom=yt,color='green',width=barwidth,label='IG')
plt.xlabel('day')
plt.ylabel('time spend in min')
plt.title('time spend on social media')
plt.xticks(xpos,x)
plt.legend()

# %% [markdown]
# ### BAR CHART

# %%
import matplotlib.pyplot as plt

# Sample data
genders = ['Male', 'Female', 'Other']
counts = [40, 30, 30]

# Create a figure and axis
fig, ax = plt.subplots()

# Create a bar chart
ax.bar(genders, counts)

# Set title and labels
ax.set_title('Distribution of Genders')
ax.set_xlabel('Gender')
ax.set_ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ### HISTOGRAM

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
ages = np.random.normal(30, 10, 100)  # Generate 100 random ages with a mean of 30 and standard deviation of 10

# Create a figure and axis
fig, ax = plt.subplots()

# Create a histogram
ax.hist(ages, bins=10, edgecolor='black')

# Set title and labels
ax.set_title('Distribution of Ages')
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### PIE CHART

# %%
import matplotlib.pyplot as plt

# Sample data
genders = ['Male', 'Female', 'Other']
counts = [40, 30, 30]

# Create a figure and axis
fig, ax = plt.subplots()

# Create a pie chart
ax.pie(counts, labels=genders, autopct='%1.1f%%')

# Set title
ax.set_title('Distribution of Genders')

# Show the plot
plt.show()

# %% [markdown]
# ### BOX PLOT MODEL

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
ages = np.random.normal(30, 10, 100)  # Generate 100 random ages with a mean of 30 and standard deviation of 10

# Create a figure and axis
fig, ax = plt.subplots()

# Create a box plot
ax.boxplot(ages)

# Set title and labels
ax.set_title('Distribution of Ages')
ax.set_xlabel('Age')
ax.set_ylabel('Value')

# Show the plot
plt.show()

# %% [markdown]
# ### DENSITY MODEL

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Sample data
ages = np.random.normal(30, 10, 100)  # Generate 100 random ages with a mean of 30 and standard deviation of 10

# Create a figure and axis
fig, ax = plt.subplots()

# Create a density plot
sns.kdeplot(ages, ax=ax)

# Set title and labels
ax.set_title('Distribution of Ages')
ax.set_xlabel('Age')
ax.set_ylabel('Density')

# Show the plot
plt.show()

# %% [markdown]
# ### LINE GRAPH MODEL

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
ages = np.random.normal(30, 10, 100)  # Generate 100 random ages with a mean of 30 and standard deviation of 10

# Create a figure and axis
fig, ax = plt.subplots()

# Create a line graph model
ax.plot(ages)

# Set title and labels
ax.set_title('Distribution of Ages')
ax.set_xlabel('Index')
ax.set_ylabel('Age')

# Show the plot
plt.show()

# %% [markdown]
# ### AREA CHART MODEL

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
ages = np.random.normal(30, 10, 100)  # Generate 100 random ages with a mean of 30 and standard deviation of 10

# Create a figure and axis
fig, ax = plt.subplots()

# Create an area chart model
ax.fill_between(range(len(ages)), ages)

# Set title and labels
ax.set_title('Distribution of Ages')
ax.set_xlabel('Index')
ax.set_ylabel('Age')

# Show the plot
plt.show()

# %% [markdown]
# ### SCATTER PLOT MODEL

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a figure and axis
fig, ax = plt.subplots()

# Create a scatter plot
ax.scatter(x, y)

# Set title and labels
ax.set_title('Scatter Plot Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# ### HEATMAP MODEL

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.random.rand(10, 10)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a heatmap model
sns.heatmap(data, ax=ax, cmap='coolwarm', annot=True)

# Set title
ax.set_title('Heatmap Example')

# Show the plot
plt.show()

# %% [markdown]
# ## SCATTER MODEL

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.random.rand(100)
y = np.random.rand(100)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a scatter model
ax.scatter(x, y)

# Set title and labels
ax.set_title('Scatter Plot Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# ### SCATTER MODEL WITH COLOR

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.random.rand(100)
y = np.random.rand(100)
colors = np.random.rand(100)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a scatter model with color
ax.scatter(x, y, c=colors)

# Set title and labels
ax.set_title('Scatter Plot Example with Color')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# ### SCATTER MODEL WITH SIZE

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.random.rand(100)
y = np.random.rand(100)
sizes = np.random.rand(100) * 100

# Create a figure and axis
fig, ax = plt.subplots()

# Create a scatter model with size
ax.scatter(x, y, s=sizes)

# Set title and labels
ax.set_title('Scatter Plot Example with Size')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# ### HORIZONTAL BAR CHART

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.random.rand(10)
y = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# Create a figure and axis
fig, ax = plt.subplots()

# Create a horizontal bar chart
ax.barh(y, x)

# Set title and labels
ax.set_title('Horizontal Bar Chart Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# ### STACKED BAR CHART

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x1 = np.random.rand(10)
x2 = np.random.rand(10)
y = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# Create a figure and axis
fig, ax = plt.subplots()

# Create a stacked bar chart
ax.bar(y, x1, label='Group 1')
ax.bar(y, x2, bottom=x1, label='Group 2')

# Set title and labels
ax.set_title('Stacked Bar Chart Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### GROUPED BAR CHART

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x1 = np.random.rand(10)
x2 = np.random.rand(10)
y = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# Create a figure and axis
fig, ax = plt.subplots()

# Create a grouped bar chart
bar_width = 0.35
ax.bar(np.arange(len(y)) - bar_width/2, x1, bar_width, label='Group 1')
ax.bar(np.arange(len(y)) + bar_width/2, x2, bar_width, label='Group 2')

# Set title and labels
ax.set_title('Grouped Bar Chart Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_xticks(np.arange(len(y)))
ax.set_xticklabels(y)
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### SIMPLE HISTOGRAM

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.random.randn(1000)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a histogram
ax.hist(x, bins=30, density=True)

# Set title and labels
ax.set_title('Histogram Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### MULTIPLE HISTOGRAM

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x1 = np.random.randn(1000)
x2 = np.random.randn(1000)

# Create a figure and axis
fig, ax = plt.subplots()

# Create multiple histograms
ax.hist(x1, bins=30, alpha=0.5, label='Group 1')
ax.hist(x2, bins=30, alpha=0.5, label='Group 2')

# Set title and labels
ax.set_title('Multiple Histograms Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Frequency')
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### 2D HISTOGRAM

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.random.randn(1000)
y = np.random.randn(1000)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a 2D histogram
ax.hist2d(x, y, bins=30, cmap='coolwarm')

# Set title and labels
ax.set_title('2D Histogram Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# ### HEXBIN PLOT MODEL

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.random.randn(1000)
y = np.random.randn(1000)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a hexbin plot
ax.hexbin(x, y, gridsize=30, cmap='coolwarm')

# Set title and labels
ax.set_title('Hexbin Plot Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# ## BAR CHART FOR CATEGORICAL VARIABLE (GENDER)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Sample data
data = {'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female']}
df = pd.DataFrame(data)

# Count the frequency of each gender
gender_counts = df['Gender'].value_counts()

# Create a figure and axis
fig, ax = plt.subplots()

# Create a bar chart
ax.bar(gender_counts.index, gender_counts.values)

# Set title and labels
ax.set_title('Distribution of Genders')
ax.set_xlabel('Gender')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
#  ## HISTOGRAM FOR CONTINUOUS VARIABLE(AGE)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Sample data
data = {'Age': [25, 30, 35, 20, 28, 32, 40, 38, 45, 42, 48, 50]}
df = pd.DataFrame(data)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a histogram
ax.hist(df['Age'], bins=10, edgecolor='black')

# Set title and labels
ax.set_title('Distribution of Ages')
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## BAR CHART FOR CATEGORICAL VARIABLE WITH MULTIPLE CATEGORIES (OCCUPATION)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Sample data
data = {'Occupation': ['Doctor', 'Engineer', 'Teacher', 'Lawyer', 'Doctor', 'Engineer', 'Teacher', 'Lawyer', 'Doctor', 'Engineer']}
df = pd.DataFrame(data)

# Count the frequency of each occupation
occupation_counts = df['Occupation'].value_counts()

# Create a figure and axis
fig, ax = plt.subplots()

# Create a bar chart
ax.bar(occupation_counts.index, occupation_counts.values)

# Set title and labels
ax.set_title('Distribution of Occupations')
ax.set_xlabel('Occupation')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## HISTOGRAM FOR CONTINUOUS VARIABLE WITH MULTIPLE PEAKS(iq scores)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats

# Sample data
data = {'IQ Score': np.random.normal(100, 15, 100)}
df = pd.DataFrame(data)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a histogram
ax.hist(df['IQ Score'], bins=20, edgecolor='black', alpha=0.5)

# Fit a normal distribution to the data
mean, std = stats.norm.fit(df['IQ Score'])
x = np.linspace(mean - 3*std, mean + 3*std, 100)
ax.plot(x, stats.norm.pdf(x, mean, std), 'r')

# Set title and labels
ax.set_title('Distribution of IQ Scores')
ax.set_xlabel('IQ Score')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()
